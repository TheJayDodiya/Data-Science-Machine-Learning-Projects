# %%
import numpy as np
import cv2
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
img = cv2.imread('test_images/sk.jpeg')

# %%
img.shape
# Out:
# (448, 800, 3)

# %%
plt.imshow(img)

# %%
gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)

# %%
gray.shape
# Out:
# (448, 800)

# %%
gray
# Out:
# array([[252, 252, 252, ..., 252, 252, 252],
#        [252, 252, 252, ..., 252, 252, 252],
#        [252, 252, 252, ..., 252, 252, 252],
#        ...,
#        [252, 252, 252, ..., 252, 252, 252],
#        [252, 252, 252, ..., 252, 252, 252],
#        [252, 252, 252, ..., 252, 252, 252]], dtype=uint8)

# %%
plt.imshow(gray,cmap='gray')

# %%
face_cascade = cv2.CascadeClassifier('./opencv/haarcascades/haarcascade_frontalface_default.xml')

# %%
eye_cascade = cv2.CascadeClassifier('./opencv/haarcascades/haarcascade_eye.xml')

# %%
faces = face_cascade.detectMultiScale(gray, 1.3, 5)
faces
# Out:
# array([[400,  92, 134, 134]], dtype=int32)

# %%
(x,y,w,h) = faces[0]

# %%
x,y,w,h
# Out:
# (400, 92, 134, 134)

# %%
face_img = cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)

# %%
plt.imshow(face_img)

# %%
cv2.destroyAllWindows()
for (x,y,w,h) in faces:
    face_img = cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
    roi_gray = gray[y:y+h, x:x+w]
    roi_color = face_img[y:y+h, x:x+w]
    eyes = eye_cascade.detectMultiScale(roi_gray)
    for (ex,ey,ew,eh) in eyes:
        cv2.rectangle(roi_color,(ex,ey),(ex+ew,ey+eh),(0,255,0),2)
        

plt.figure()
plt.imshow(face_img, cmap='gray')
plt.show()

# %%
# %matplotlib inline
plt.imshow(roi_color, cmap='gray')

# %%
cropped_img = np.array(roi_color)
cropped_img.shape
# Out:
# (134, 134, 3)

# %%
def get_cropped_image_if_2_eyes(image_path):
    img = cv2.imread(image_path)
    if(img is not None):
        gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
        faces = face_cascade.detectMultiScale(gray, 1.3, 5)
        for (x,y,w,h) in faces:
            roi_gray = gray[y:y+h, x:x+w]
            roi_color = img[y:y+h, x:x+w]
            eyes = eye_cascade.detectMultiScale(roi_gray)
            if len(eyes) >= 2:
                return roi_color

# %%
original_image = cv2.imread('test_images/sk.jpeg')
plt.imshow(original_image)

# %%
cropped_image = get_cropped_image_if_2_eyes('test_images/sk.jpeg')
plt.imshow(cropped_image)

# %%
path_to_data = "./dataset/"
path_to_cr_data = "./dataset/cropped/"

# %%
import os
img_dirs = []
for entry in os.scandir(path_to_data):
    if entry.is_dir():
        img_dirs.append(entry.path)

# %%
img_dirs
# Out:
# ['./dataset/Shiney_Ahuja',
#  './dataset/Salman_Khan',
#  './dataset/Sanjay_Dutt',
#  './dataset/cropped',
#  './dataset/John_Abraham',
#  './dataset/Saif_Ali_Khan']

# %%
import shutil
if os.path.exists(path_to_cr_data):
     shutil.rmtree(path_to_cr_data)
os.mkdir(path_to_cr_data)

# %%
cropped_image_dirs = []
celebrity_file_names_dict = {}
for img_dir in img_dirs:
    count = 1
    celebrity_name = img_dir.split('/')[-1]
    celebrity_file_names_dict[celebrity_name] = []
    for entry in os.scandir(img_dir):
        roi_color = get_cropped_image_if_2_eyes(entry.path)
        if roi_color is not None:
            cropped_folder = path_to_cr_data + celebrity_name
            if not os.path.exists(cropped_folder):
                os.makedirs(cropped_folder)
                cropped_image_dirs.append(cropped_folder)
                print("Generating cropped images in folder: ",cropped_folder)
            cropped_file_name = celebrity_name + str(count) + ".png"
            cropped_file_path = cropped_folder + "/" + cropped_file_name
            cv2.imwrite(cropped_file_path, roi_color)
            celebrity_file_names_dict[celebrity_name].append(cropped_file_path)
            count += 1
# Out:
# Generating cropped images in folder:  ./dataset/cropped/Shiney_Ahuja
# Generating cropped images in folder:  ./dataset/cropped/Salman_Khan
# Generating cropped images in folder:  ./dataset/cropped/Sanjay_Dutt
# Generating cropped images in folder:  ./dataset/cropped/John_Abraham
# Generating cropped images in folder:  ./dataset/cropped/Saif_Ali_Khan

# %%
import numpy as np
import pywt
import cv2    

def w2d(img, mode='haar', level=1):
    imArray = img
    #Datatype conversions
    #convert to grayscale
    imArray = cv2.cvtColor( imArray,cv2.COLOR_RGB2GRAY )
    #convert to float
    imArray =  np.float32(imArray)   
    imArray /= 255;
    # compute coefficients 
    coeffs=pywt.wavedec2(imArray, mode, level=level)

    #Process Coefficients
    coeffs_H=list(coeffs)  
    coeffs_H[0] *= 0;  

    # reconstruction
    imArray_H=pywt.waverec2(coeffs_H, mode);
    imArray_H *= 255;
    imArray_H =  np.uint8(imArray_H)

    return imArray_H

# %%
im_har = w2d(cropped_img,'db1',5)
plt.imshow(im_har, cmap='gray')

# %%
celebrity_file_names_dict = {}
for img_dir in cropped_image_dirs:
    celebrity_name = img_dir.split('/')[-1]
    file_list = []
    for entry in os.scandir(img_dir):
        file_list.append(entry.path)
    celebrity_file_names_dict[celebrity_name] = file_list
celebrity_file_names_dict
# Out:
# {'Shiney_Ahuja': ['./dataset/cropped/Shiney_Ahuja/Shiney_Ahuja10.png',
#   './dataset/cropped/Shiney_Ahuja/Shiney_Ahuja17.png',
#   './dataset/cropped/Shiney_Ahuja/Shiney_Ahuja9.png',
#   './dataset/cropped/Shiney_Ahuja/Shiney_Ahuja6.png',
#   './dataset/cropped/Shiney_Ahuja/Shiney_Ahuja12.png',
#   './dataset/cropped/Shiney_Ahuja/Shiney_Ahuja20.png',
#   './dataset/cropped/Shiney_Ahuja/Shiney_Ahuja1.png',
#   './dataset/cropped/Shiney_Ahuja/Shiney_Ahuja14.png',
#   './dataset/cropped/Shiney_Ahuja/Shiney_Ahuja26.png',
#   './dataset/cropped/Shiney_Ahuja/Shiney_Ahuja27.png',
#   './dataset/cropped/Shiney_Ahuja/Shiney_Ahuja18.png',
#   './dataset/cropped/Shiney_Ahuja/Shiney_Ahuja25.png',
#   './dataset/cropped/Shiney_Ahuja/Shiney_Ahuja8.png',
#   './dataset/cropped/Shiney_Ahuja/Shiney_Ahuja4.png',
#   './dataset/cropped/Shiney_Ahuja/Shiney_Ahuja11.png',
#   './dataset/cropped/Shiney_Ahuja/Shiney_Ahuja19.png',
#   './dataset/cropped/Shiney_Ahuja/Shiney_Ahuja21.png',
#   './dataset/cropped/Shiney_Ahuja/Shiney_Ahuja28.png',
#   './dataset/cropped/Shiney_Ahuja/Shiney_Ahuja24.png',
#   './dataset/cropped/Shiney_Ahuja/Shiney_Ahuja7.png',
#   './dataset/cropped/Shiney_Ahuja/Shiney_Ahuja23.png',
#   './dataset/cropped/Shiney_Ahuja/Shiney_Ahuja13.png',
#   './dataset/cropped/Shiney_Ahuja/Shiney_Ahuja30.png',
#   './dataset/cropped/Shiney_Ahuja/Shiney_Ahuja3.png',
#   './dataset/cropped/Shiney_Ahuja/Shiney_Ahuja5.png',
#   './dataset/cropped/Shiney_Ahuja/Shiney_Ahuja15.png',
#   './dataset/cropped/Shiney_Ahuja/Shiney_Ahuja29.png',
#   './dataset/cropped/Shiney_Ahuja/Shiney_Ahuja2.png',
#   './dataset/cropped/Shiney_Ahuja/Shiney_Ahuja16.png',
#   './dataset/cropped/Shiney_Ahuja/Shiney_Ahuja22.png'],
#  'Salman_Khan': ['./dataset/cropped/Salman_Khan/Salman_Khan2.png',
#   './dataset/cropped/Salman_Khan/Salman_Khan32.png',
#   './dataset/cropped/Salman_Khan/Salman_Khan16.png',
#   './dataset/cropped/Salman_Khan/Salman_Khan6.png',
#   './dataset/cropped/Salman_Khan/Salman_Khan22.png',
#   './dataset/cropped/Salman_Khan/Salman_Khan24.png',
#   './dataset/cropped/Salman_Khan/Salman_Khan25.png',
#   './dataset/cropped/Salman_Khan/Salman_Khan29.png',
#   './dataset/cropped/Salman_Khan/Salman_Khan30.png',
#   './dataset/cropped/Salman_Khan/Salman_Khan8.png',
#   './dataset/cropped/Salman_Khan/Salman_Khan28.png',
#   './dataset/cropped/Salman_Khan/Salman_Khan21.png',
#   './dataset/cropped/Salman_Khan/Salman_Khan14.png',
#   './dataset/cropped/Salman_Khan/Salman_Khan23.png',
#   './dataset/cropped/Salman_Khan/Salman_Khan5.png',
#   './dataset/cropped/Salman_Khan/Salman_Khan40.png',
#   './dataset/cropped/Salman_Khan/Salman_Khan18.png',
#   './dataset/cropped/Salman_Khan/Salman_Khan35.png',
#   './dataset/cropped/Salman_Khan/Salman_Khan9.png',
#   './dataset/cropped/Salman_Khan/Salman_Khan13.png',
#   './dataset/cropped/Salman_Khan/Salman_Khan3.png',
#   './dataset/cropped/Salman_Khan/Salman_Khan33.png',
#   './dataset/cropped/Salman_Khan/Salman_Khan27.png',
#   './dataset/cropped/Salman_Khan/Salman_Khan15.png',
#   './dataset/cropped/Salman_Khan/Salman_Khan17.png',
#   './dataset/cropped/Salman_Khan/Salman_Khan41.png',
#   './dataset/cropped/Salman_Khan/Salman_Khan10.png',
#   './dataset/cropped/Salman_Khan/Salman_Khan31.png',
#   './dataset/cropped/Salman_Khan/Salman_Khan39.png',
#   './dataset/cropped/Salman_Khan/Salman_Khan20.png',
#   './dataset/cropped/Salman_Khan/Salman_Khan1.png',
#   './dataset/cropped/Salman_Khan/Salman_Khan36.png',
#   './dataset/cropped/Salman_Khan/Salman_Khan38.png',
#   './dataset/cropped/Salman_Khan/Salman_Khan26.png',
#   './dataset/cropped/Salman_Khan/Salman_Khan4.png',
#   './dataset/cropped/Salman_Khan/Salman_Khan11.png',
#   './dataset/cropped/Salman_Khan/Salman_Khan12.png',
#   './dataset/cropped/Salman_Khan/Salman_Khan7.png',
#   './dataset/cropped/Salman_Khan/Salman_Khan34.png',
#   './dataset/cropped/Salman_Khan/Salman_Khan37.png',
#   './dataset/cropped/Salman_Khan/Salman_Khan19.png'],
#  'Sanjay_Dutt': ['./dataset/cropped/Sanjay_Dutt/Sanjay_Dutt32.png',
#   './dataset/cropped/Sanjay_Dutt/Sanjay_Dutt18.png',
#   './dataset/cropped/Sanjay_Dutt/Sanjay_Dutt30.png',
#   './dataset/cropped/Sanjay_Dutt/Sanjay_Dutt7.png',
#   './dataset/cropped/Sanjay_Dutt/Sanjay_Dutt4.png',
#   './dataset/cropped/Sanjay_Dutt/Sanjay_Dutt8.png',
#   './dataset/cropped/Sanjay_Dutt/Sanjay_Dutt12.png',
#   './dataset/cropped/Sanjay_Dutt/Sanjay_Dutt9.png',
#   './dataset/cropped/Sanjay_Dutt/Sanjay_Dutt31.png',
#   './dataset/cropped/Sanjay_Dutt/Sanjay_Dutt22.png',
#   './dataset/cropped/Sanjay_Dutt/Sanjay_Dutt13.png',
#   './dataset/cropped/Sanjay_Dutt/Sanjay_Dutt6.png',
#   './dataset/cropped/Sanjay_Dutt/Sanjay_Dutt15.png',
#   './dataset/cropped/Sanjay_Dutt/Sanjay_Dutt10.png',
#   './dataset/cropped/Sanjay_Dutt/Sanjay_Dutt28.png',
#   './dataset/cropped/Sanjay_Dutt/Sanjay_Dutt19.png',
#   './dataset/cropped/Sanjay_Dutt/Sanjay_Dutt23.png',
#   './dataset/cropped/Sanjay_Dutt/Sanjay_Dutt2.png',
#   './dataset/cropped/Sanjay_Dutt/Sanjay_Dutt29.png',
#   './dataset/cropped/Sanjay_Dutt/Sanjay_Dutt17.png',
#   './dataset/cropped/Sanjay_Dutt/Sanjay_Dutt14.png',
#   './dataset/cropped/Sanjay_Dutt/Sanjay_Dutt16.png',
#   './dataset/cropped/Sanjay_Dutt/Sanjay_Dutt20.png',
#   './dataset/cropped/Sanjay_Dutt/Sanjay_Dutt26.png',
#   './dataset/cropped/Sanjay_Dutt/Sanjay_Dutt11.png',
#   './dataset/cropped/Sanjay_Dutt/Sanjay_Dutt27.png',
#   './dataset/cropped/Sanjay_Dutt/Sanjay_Dutt5.png',
#   './dataset/cropped/Sanjay_Dutt/Sanjay_Dutt21.png',
#   './dataset/cropped/Sanjay_Dutt/Sanjay_Dutt1.png',
#   './dataset/cropped/Sanjay_Dutt/Sanjay_Dutt24.png',
#   './dataset/cropped/Sanjay_Dutt/Sanjay_Dutt25.png',
#   './dataset/cropped/Sanjay_Dutt/Sanjay_Dutt3.png'],
#  'John_Abraham': ['./dataset/cropped/John_Abraham/John_Abraham25.png',
#   './dataset/cropped/John_Abraham/John_Abraham22.png',
#   './dataset/cropped/John_Abraham/John_Abraham8.png',
#   './dataset/cropped/John_Abraham/John_Abraham32.png',
#   './dataset/cropped/John_Abraham/John_Abraham27.png',
#   './dataset/cropped/John_Abraham/John_Abraham26.png',
#   './dataset/cropped/John_Abraham/John_Abraham33.png',
#   './dataset/cropped/John_Abraham/John_Abraham18.png',
#   './dataset/cropped/John_Abraham/John_Abraham9.png',
#   './dataset/cropped/John_Abraham/John_Abraham5.png',
#   './dataset/cropped/John_Abraham/John_Abraham29.png',
#   './dataset/cropped/John_Abraham/John_Abraham21.png',
#   './dataset/cropped/John_Abraham/John_Abraham14.png',
#   './dataset/cropped/John_Abraham/John_Abraham28.png',
#   './dataset/cropped/John_Abraham/John_Abraham7.png',
#   './dataset/cropped/John_Abraham/John_Abraham4.png',
#   './dataset/cropped/John_Abraham/John_Abraham3.png',
#   './dataset/cropped/John_Abraham/John_Abraham31.png',
#   './dataset/cropped/John_Abraham/John_Abraham30.png',
#   './dataset/cropped/John_Abraham/John_Abraham19.png',
#   './dataset/cropped/John_Abraham/John_Abraham24.png',
#   './dataset/cropped/John_Abraham/John_Abraham23.png',
#   './dataset/cropped/John_Abraham/John_Abraham1.png',
#   './dataset/cropped/John_Abraham/John_Abraham20.png',
#   './dataset/cropped/John_Abraham/John_Abraham13.png',
#   './dataset/cropped/John_Abraham/John_Abraham6.png',
#   './dataset/cropped/John_Abraham/John_Abraham17.png',
#   './dataset/cropped/John_Abraham/John_Abraham10.png',
#   './dataset/cropped/John_Abraham/John_Abraham34.png',
#   './dataset/cropped/John_Abraham/John_Abraham16.png',
#   './dataset/cropped/John_Abraham/John_Abraham11.png',
#   './dataset/cropped/John_Abraham/John_Abraham12.png',
#   './dataset/cropped/John_Abraham/John_Abraham15.png',
#   './dataset/cropped/John_Abraham/John_Abraham2.png'],
#  'Saif_Ali_Khan': ['./dataset/cropped/Saif_Ali_Khan/Saif_Ali_Khan4.png',
#   './dataset/cropped/Saif_Ali_Khan/Saif_Ali_Khan41.png',
#   './dataset/cropped/Saif_Ali_Khan/Saif_Ali_Khan19.png',
#   './dataset/cropped/Saif_Ali_Khan/Saif_Ali_Khan24.png',
#   './dataset/cropped/Saif_Ali_Khan/Saif_Ali_Khan9.png',
#   './dataset/cropped/Saif_Ali_Khan/Saif_Ali_Khan39.png',
#   './dataset/cropped/Saif_Ali_Khan/Saif_Ali_Khan7.png',
#   './dataset/cropped/Saif_Ali_Khan/Saif_Ali_Khan29.png',
#   './dataset/cropped/Saif_Ali_Khan/Saif_Ali_Khan42.png',
#   './dataset/cropped/Saif_Ali_Khan/Saif_Ali_Khan34.png',
#   './dataset/cropped/Saif_Ali_Khan/Saif_Ali_Khan31.png',
#   './dataset/cropped/Saif_Ali_Khan/Saif_Ali_Khan33.png',
#   './dataset/cropped/Saif_Ali_Khan/Saif_Ali_Khan45.png',
#   './dataset/cropped/Saif_Ali_Khan/Saif_Ali_Khan13.png',
#   './dataset/cropped/Saif_Ali_Khan/Saif_Ali_Khan6.png',
#   './dataset/cropped/Saif_Ali_Khan/Saif_Ali_Khan38.png',
#   './dataset/cropped/Saif_Ali_Khan/Saif_Ali_Khan32.png',
#   './dataset/cropped/Saif_Ali_Khan/Saif_Ali_Khan30.png',
#   './dataset/cropped/Saif_Ali_Khan/Saif_Ali_Khan25.png',
#   './dataset/cropped/Saif_Ali_Khan/Saif_Ali_Khan16.png',
#   './dataset/cropped/Saif_Ali_Khan/Saif_Ali_Khan12.png',
#   './dataset/cropped/Saif_Ali_Khan/Saif_Ali_Khan2.png',
#   './dataset/cropped/Saif_Ali_Khan/Saif_Ali_Khan18.png',
#   './dataset/cropped/Saif_Ali_Khan/Saif_Ali_Khan36.png',
#   './dataset/cropped/Saif_Ali_Khan/Saif_Ali_Khan17.png',
#   './dataset/cropped/Saif_Ali_Khan/Saif_Ali_Khan43.png',
#   './dataset/cropped/Saif_Ali_Khan/Saif_Ali_Khan22.png',
#   './dataset/cropped/Saif_Ali_Khan/Saif_Ali_Khan21.png',
#   './dataset/cropped/Saif_Ali_Khan/Saif_Ali_Khan10.png',
#   './dataset/cropped/Saif_Ali_Khan/Saif_Ali_Khan23.png',
#   './dataset/cropped/Saif_Ali_Khan/Saif_Ali_Khan11.png',
#   './dataset/cropped/Saif_Ali_Khan/Saif_Ali_Khan1.png',
#   './dataset/cropped/Saif_Ali_Khan/Saif_Ali_Khan26.png',
#   './dataset/cropped/Saif_Ali_Khan/Saif_Ali_Khan3.png',
#   './dataset/cropped/Saif_Ali_Khan/Saif_Ali_Khan46.png',
#   './dataset/cropped/Saif_Ali_Khan/Saif_Ali_Khan28.png',
#   './dataset/cropped/Saif_Ali_Khan/Saif_Ali_Khan5.png',
#   './dataset/cropped/Saif_Ali_Khan/Saif_Ali_Khan35.png',
#   './dataset/cropped/Saif_Ali_Khan/Saif_Ali_Khan27.png',
#   './dataset/cropped/Saif_Ali_Khan/Saif_Ali_Khan20.png',
#   './dataset/cropped/Saif_Ali_Khan/Saif_Ali_Khan14.png',
#   './dataset/cropped/Saif_Ali_Khan/Saif_Ali_Khan8.png',
#   './dataset/cropped/Saif_Ali_Khan/Saif_Ali_Khan15.png',
#   './dataset/cropped/Saif_Ali_Khan/Saif_Ali_Khan40.png',
#   './dataset/cropped/Saif_Ali_Khan/Saif_Ali_Khan44.png',
#   './dataset/cropped/Saif_Ali_Khan/Saif_Ali_Khan37.png']}

# %%
class_dict = {}
count = 0
for celebrity_name in celebrity_file_names_dict.keys():
    class_dict[celebrity_name] = count
    count = count + 1
class_dict
# Out:
# {'Shiney_Ahuja': 0,
#  'Salman_Khan': 1,
#  'Sanjay_Dutt': 2,
#  'John_Abraham': 3,
#  'Saif_Ali_Khan': 4}

# %%
X, y = [], []
for celebrity_name, training_files in celebrity_file_names_dict.items():
    for training_image in training_files:
        img = cv2.imread(training_image)
        scalled_raw_img = cv2.resize(img, (32, 32))
        img_har = w2d(img,'db1',5)
        scalled_img_har = cv2.resize(img_har, (32, 32))
        combined_img = np.vstack((scalled_raw_img.reshape(32*32*3,1),scalled_img_har.reshape(32*32,1)))
        X.append(combined_img)
        y.append(class_dict[celebrity_name])

# %%
len(X[0])
# Out:
# 4096

# %%
X[0]
# Out:
# array([[ 40],
#        [ 37],
#        [ 45],
#        ...,
#        [  6],
#        [ 21],
#        [159]], dtype=uint8)

# %%
X = np.array(X).reshape(len(X),4096).astype(float)
X.shape
# Out:
# (183, 4096)

# %%
from sklearn.svm import SVC
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline
from sklearn.metrics import classification_report

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0)

pipe = Pipeline([('scaler', StandardScaler()), ('svc', SVC(kernel = 'rbf', C = 10))])
pipe.fit(X_train, y_train)
pipe.score(X_test, y_test)
# Out:
# 0.6086956521739131

# %%
print(classification_report(y_test, pipe.predict(X_test)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.80      0.57      0.67         7
#            1       0.89      0.67      0.76        12
#            2       0.67      0.20      0.31        10
#            3       0.36      0.83      0.50         6
#            4       0.60      0.82      0.69        11
#
#     accuracy                           0.61        46
#    macro avg       0.66      0.62      0.59        46
# weighted avg       0.69      0.61      0.60        46

# %%
from sklearn import svm
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import make_pipeline
from sklearn.model_selection import GridSearchCV

# %%
model_params = {
    'svm': {
        'model': svm.SVC(gamma='auto',probability=True),
        'params' : {
            'svc__C': [1,10,100,1000],
            'svc__kernel': ['rbf','linear']
        }  
    },
    'random_forest': {
        'model': RandomForestClassifier(),
        'params' : {
            'randomforestclassifier__n_estimators': [1,5,10]
        }
    },
    'logistic_regression' : {
        'model': LogisticRegression(solver='liblinear',multi_class='auto'),
        'params': {
            'logisticregression__C': [1,5,10]
        }
    }
}

# %%
scores = []
best_estimators = {}
import pandas as pd
for algo, mp in model_params.items():
    pipe = make_pipeline(StandardScaler(), mp['model'])
    clf =  GridSearchCV(pipe, mp['params'], cv=5, return_train_score=False)
    clf.fit(X_train, y_train)
    scores.append({
        'model': algo,
        'best_score': clf.best_score_,
        'best_params': clf.best_params_
    })
    best_estimators[algo] = clf.best_estimator_
    
df = pd.DataFrame(scores,columns=['model','best_score','best_params'])
df
# Out:
#                  model  best_score  \
# 0                  svm    0.671693
# 1        random_forest    0.387566
# 2  logistic_regression    0.665079
#
#                                     best_params
# 0        {'svc__C': 1, 'svc__kernel': 'linear'}
# 1  {'randomforestclassifier__n_estimators': 10}
# 2                  {'logisticregression__C': 1}

# %%
best_estimators
# Out:
# {'svm': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('svc',
#                   SVC(C=1, gamma='auto', kernel='linear', probability=True))]),
#  'random_forest': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('randomforestclassifier',
#                   RandomForestClassifier(n_estimators=10))]),
#  'logistic_regression': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('logisticregression',
#                   LogisticRegression(C=1, solver='liblinear'))])}

# %%
best_estimators['svm'].score(X_test,y_test)
# Out:
# 0.6956521739130435

# %%
best_estimators['random_forest'].score(X_test,y_test)
# Out:
# 0.3695652173913043

# %%
best_estimators['logistic_regression'].score(X_test,y_test)
# Out:
# 0.7391304347826086

# %%
best_clf = best_estimators['svm']
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, best_clf.predict(X_test))
cm
# Out:
# array([[5, 1, 0, 0, 1],
#        [2, 8, 0, 2, 0],
#        [0, 1, 7, 0, 2],
#        [0, 0, 2, 3, 1],
#        [0, 0, 0, 2, 9]])

# %%
import seaborn as sn
plt.figure(figsize = (10,7))
sn.heatmap(cm, annot=True)
plt.xlabel('Predicted')
plt.ylabel('Truth')
# Out:
# Text(69.0, 0.5, 'Truth')

# %%
best_clf = best_estimators['logistic_regression']
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, best_clf.predict(X_test))
cm
# Out:
# array([[5, 1, 0, 0, 1],
#        [3, 9, 0, 0, 0],
#        [0, 1, 9, 0, 0],
#        [0, 0, 1, 3, 2],
#        [1, 0, 0, 2, 8]])

# %%
import seaborn as sn
plt.figure(figsize = (10,7))
sn.heatmap(cm, annot=True)
plt.xlabel('Predicted')
plt.ylabel('Truth')
# Out:
# Text(69.0, 0.5, 'Truth')

# %%
# !pip install joblib
import joblib 
# Save the model as a pickle in a file 
joblib.dump(best_clf, 'saved_model.pkl')
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: joblib in /home/jaydodia/.local/lib/python3.8/site-packages (1.1.0)
# ['saved_model.pkl']

# %%
import json
with open("class_dictionary.json","w") as f:
    f.write(json.dumps(class_dict))
